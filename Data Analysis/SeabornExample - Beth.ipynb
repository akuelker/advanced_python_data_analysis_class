# %%
 #may have seaborn 0.8
    ### Importing necessary library  
import random  
import numpy as np  
import pandas as pd  
import seaborn as sns  
import matplotlib.pyplot as plt  
# %matplotlib inline 
df = pd.read_csv('PopUp Toy Store4_5.csv').fillna(0)
x = np.array([ 0, 0.53, 1.05, 1.58, 2.11, 2.63, 3.16, 3.68, 4.21,  
        4.74, 5.26, 5.79, 6.32, 6.84])  
y = np.array([ 0, 0.51, 0.87, 1. , 0.86, 0.49, -0.02, -0.51, -0.88,  
        -1. , -0.85, -0.47, 0.04, 0.53])  
fig, ax = plt.subplots()  
ax.plot(x, y)  
ax.set_xlabel('X data')  
ax.set_ylabel('Y data')  
ax.set_title('Relationship between variables X and Y')  
plt.show() # display the graph

# %%
 ### Importing necessary library  
import numpy as np  
import pandas as pd  
import seaborn as sns  
import matplotlib.pyplot as plt  
# %matplotlib inline 
df = pd.read_csv('PopUp Toy Store4_5.csv').fillna(0)

df.columns = ['Week', 'Day', 'Airplanes', 
                'Sticks', 'Weather']
sns.kdeplot(df.Airplanes)

# %%
df.head
# Out:
# <bound method NDFrame.head of     Week        Day  Airplanes  Sticks Weather
# 0      4     Monday       89.0    16.0       0
# 1      4    Tuesday       19.0     7.0       0
# 2      4  Wednesday      118.0     5.0       0
# 3      4   Thursday       29.0    40.0       0
# 4      4     Friday       58.0    11.0    Rain
# 5      4   Saturday      193.0    58.0    Nice
# 6      4     Sunday       57.0     9.0    Snow
# 7      5     Monday        5.0     2.0       0
# 8      5    Tuesday       10.0     2.0    Rain
# 9      5  Wednesday        6.0     2.0    Snow
# 10     5   Thursday       80.0     5.0    Snow
# 11     5     Friday        0.0     0.0    Snow
# 12     5   Saturday       98.0    12.0    Snow
# 13     5     Sunday      185.0   116.0    Nice>

# %%
plt.ylabel = 'Toys'
plt.xlabel = 'Anything'
sns.kdeplot(df.Sticks, df.Week)
#sns.kdeplot(df.Airplanes, df.Week)

# %%
sns.distplot(df.Sticks)

# %%
 ### Importing necessary library  
sns.violinplot(df.Sticks)

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
tips = sns.load_dataset("tips")

# Create violinplot
sns.violinplot(x = "total_bill", data=tips)

# Show the plot
plt.show()
